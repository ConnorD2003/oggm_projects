# %%
from oggm import cfg, utils
cfg.initialize()
# Out:
# 2026-04-09 18:14:07: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2026-04-09 18:14:07: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2026-04-09 18:14:07: oggm.cfg: Multiprocessing: using all available processors (N=16)

# %%
cfg.PARAMS['melt_f'], cfg.PARAMS['ice_density'], cfg.PARAMS['continue_on_error']
# Out:
# (5.0, 900.0, False)
