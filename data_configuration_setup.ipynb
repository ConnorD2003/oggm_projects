# %%
from oggm import cfg
cfg.initialize()
# Out:
# 2026-04-09 17:51:19: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2026-04-09 17:51:19: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2026-04-09 17:51:19: oggm.cfg: Multiprocessing: using all available processors (N=16)

# %%
print(cfg.CONFIG_FILE)
# Out:
# /home/cdill/.oggm_config
