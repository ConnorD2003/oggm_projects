# %%
from oggm import cfg
cfg.initialize()
# Out:
# 2026-04-10 10:27:00: oggm.cfg: Reading default parameters from the OGGM `params.cfg` configuration file.
# 2026-04-10 10:27:00: oggm.cfg: Multiprocessing switched OFF according to the parameter file.
# 2026-04-10 10:27:00: oggm.cfg: Multiprocessing: using all available processors (N=16)

# %%
from oggm import utils

# Create the permanent working directory
working_dir = utils.mkdir('/home/cdill/oggm_projects/Models_for_Thesis/')
cfg.PATHS['working_dir'] = working_dir

# Verify the path
print(f"Working directory set to: {cfg.PATHS['working_dir']}")
# Out:
# Working directory set to: /home/cdill/oggm_projects/Models_for_Thesis/

# %%
print(cfg.CONFIG_FILE)
# Out:
# /home/cdill/.oggm_config
